# %%
import numpy as np

# %%
datContentTrain = [i.strip().split() for i in open("./hw6_train.dat").readlines()]
for i in range(len(datContentTrain)):
    for j in range(len(datContentTrain[i])):
        datContentTrain[i][j] = float(datContentTrain[i][j])
data_train = np.array(datContentTrain)

datContentTest = [i.strip().split() for i in open("./hw6_test.dat").readlines()]
for i in range(len(datContentTest)):
    for j in range(len(datContentTest[i])):
        datContentTest[i][j] = float(datContentTest[i][j])
data_test = np.array(datContentTest)

# %%
X_train = data_train[:, :-1]
y_train = data_train[:, -1]
X_test = data_test[:, :-1]
y_test = data_test[:, -1]

# %%
class Adaboost:
    def __init__(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train
        self.weak_clfs = None
        self.u = None

    def initialize(self):
        u = np.repeat(1/self.X_train.shape[0], self.X_train.shape[0])
        return u

    def binary_to_diamond_arr(self, arr, diamond):
        """ 
        arr: binary array
        diamond: diamond value in adaboost
        Map (0, 1) to (n, 1/n) 
        """
        arr_ = ( (1-diamond**2) / diamond ) * arr + diamond
        return arr_

    def decision_stump(self):
        best_i = 0
        best_err = np.inf            
        best_threshold = 0
        best_decision = 0
        best_pred = None

        for i in range(self.X_train.shape[1]):
            #select feature i 
            selected_features = np.sort(self.X_train[:, i])
            thresholds = np.concatenate(
                [np.array([-np.inf]), 
                (selected_features[1:] + selected_features[:-1]) / 2]
            )

            #test all threshold in features i 
            for threshold in thresholds:
                for decision in [1, -1]:
                    #when feature > threshold, predict +1
                    if decision == 1: 
                        y_pred = self.binary_to_sign(
                            self.X_train[:, i] >= threshold
                            )
                    #when feature > threshold, predict -1
                    else: 
                        y_pred = self.binary_to_sign(
                            self.X_train[:, i] < threshold
                            )                
                            
                    weight_err = self.compute_weighted_error(y_pred)
                    if weight_err < best_err:
                        best_i = i
                        best_err = weight_err
                        best_threshold = threshold
                        best_decision = decision
                        best_pred = y_pred
        return best_i, best_threshold, best_decision, best_err, best_pred

    def train(self, max_iter = 500, verbose = False):
        weak_clfs = {
            "iter": [],
            "feat_idx": [],
            "thres": [],
            "decision": [],
            "alpha": [],
            "g_err_rate": [],
            "g_weight_err_rate": [],
            "G_err_rate": [],
            "pred": []
        }
        strong_clf = np.zeros(self.X_train.shape[0])
        self.u = self.initialize()
        for i in range(max_iter):
            feature_idx, threshold, decision, weight_err, pred = self.decision_stump()
            clf_result = (pred == self.y_train)
            err_rate = np.sum(1-clf_result) / self.X_train.shape[0]
            weight_err_rate = weight_err / np.sum(self.u)
            diamond = np.sqrt(
                (1-weight_err_rate) / weight_err_rate
            )
            diamond_arr = self.binary_to_diamond_arr(clf_result, diamond)
            self.u = self.u * diamond_arr
            alpha = np.log(diamond)
            strong_clf += alpha * pred
            strong_clf_pred = np.sign(strong_clf)
            strong_clf_err_rate = np.sum(
                (strong_clf_pred != self.y_train)
            ) / self.X_train.shape[0]

            #store records
            weak_clfs["iter"].append(i)
            weak_clfs["feat_idx"].append(feature_idx)
            weak_clfs["thres"].append(threshold)
            weak_clfs["decision"].append(decision)
            weak_clfs["alpha"].append(alpha)
            weak_clfs["g_err_rate"].append(err_rate)
            weak_clfs["g_weight_err_rate"].append(weight_err_rate)
            weak_clfs["G_err_rate"].append(strong_clf_err_rate)
            weak_clfs["pred"].append(pred)

            if verbose:
                print(
                    f"iter {i+1}: feat idx = {feature_idx}, thres = {round(threshold, 3)}",
                    f"s = {decision}, alpha = {round(alpha, 3)}, E_in(g) = {round(err_rate*100, 3)}%", 
                    f", E_in(G) = {round(strong_clf_err_rate*100, 3)}%"
                    )
        if verbose:
            print(f"Final error rate: {round(strong_clf_err_rate * 100, 4)}%")
        self.weak_clfs = weak_clfs
        return weak_clfs

    def predict(self, X_test, y_test, num_iter, isUniform = False, verbose = False):
        g_err_rate_record = []
        G_err_rate_record = []
        strong_clf = np.zeros(self.X_train.shape[0])
        for idx in range(num_iter):
            feature_idx = self.weak_clfs["feat_idx"][idx]
            if self.weak_clfs["decision"][idx] == 1:
                weak_pred = self.binary_to_sign(
                    X_test[:, feature_idx] >= self.weak_clfs["thres"][idx]
                )
            else:
                weak_pred = self.binary_to_sign(
                    X_test[:, feature_idx] < self.weak_clfs["thres"][idx]
                )
            if isUniform:
                strong_clf += weak_pred
            else:
                strong_clf += self.weak_clfs["alpha"][idx] * weak_pred
            strong_clf_pred = np.sign(strong_clf)

            g_err_rate = self.compute_error_rate(
                weak_pred, y_test
            )
            G_err_rate = self.compute_error_rate(
                strong_clf_pred, y_test
            )
            g_err_rate_record.append(g_err_rate)
            G_err_rate_record.append(G_err_rate)
            if verbose:
                print(f"Iter {idx}: E_in(g) = {round(g_err_rate, 4)}%, E_in(G) = {round(G_err_rate, 4)}%")
        return g_err_rate_record, G_err_rate_record

    def compute_error_rate(self, y_pred, y_true):
        err_rate = np.sum(
                (y_pred != y_true)
            ) / self.X_train.shape[0]
        return err_rate

    def compute_weighted_error(self, y_pred):
        return np.dot((y_pred != y_train), self.u)

    def binary_to_sign(self, arr):
        """
        Map (0, 1) to (-1, 1)
        """
        return arr * 2 - 1

# %% [markdown]
# # Problem 11

# %%
num_iter = 1
adaboost_clf = Adaboost(X_train, y_train)
clf_results = adaboost_clf.train(num_iter, verbose=True)
# Out:
# iter 1: feat idx=9, thres = 0.448 s = -1, alpha = 0.258, E_in(g) = 37.4% , E_in(G) = 37.4%
# Final error rate: 37.4%

# %% [markdown]
# # Problem 12

# %%
num_iter = 500
adaboost_clf = Adaboost(X_train, y_train)
clf_result = adaboost_clf.train(num_iter, verbose=True)
# Out:
# iter 1: feat idx = 9, thres = 0.448 s = -1, alpha = 0.258, E_in(g) = 37.4% , E_in(G) = 37.4%
# iter 2: feat idx = 0, thres = 2.679 s = 1, alpha = 0.212, E_in(g) = 42.8% , E_in(G) = 37.4%
# iter 3: feat idx = 0, thres = -1.514 s = -1, alpha = 0.205, E_in(g) = 44.1% , E_in(G) = 31.8%
# iter 4: feat idx = 5, thres = -1.247 s = 1, alpha = 0.283, E_in(g) = 39.6% , E_in(G) = 34.5%
# iter 5: feat idx = 0, thres = 3.826 s = 1, alpha = 0.177, E_in(g) = 45.9% , E_in(G) = 30.4%
# iter 6: feat idx = 8, thres = -0.587 s = 1, alpha = 0.188, E_in(g) = 41.4% , E_in(G) = 30.8%
# iter 7: feat idx = 0, thres = -2.253 s = -1, alpha = 0.179, E_in(g) = 44.0% , E_in(G) = 30.2%
# iter 8: feat idx = 7, thres = -0.676 s = 1, alpha = 0.201, E_in(g) = 42.1% , E_in(G) = 29.7%
# iter 9: feat idx = 5, thres = 2.947 s = 1, alpha = 0.13, E_in(g) = 49.9% , E_in(G) = 29.1%
# iter 10: feat idx = 8, thres = 0.518 s = -1, alpha = 0.18, E_in(g) = 43.8% , E_in(G) = 25.6%
# iter 11: feat idx = 0, thres = 1.447 s = 1, alpha = 0.127, E_in(g) = 44.6% , E_in(G) = 25.4%
# iter 12: feat idx = 9, thres = 0.794 s = -1, alpha = 0.133, E_in(g) = 37.9% , E_in(G) = 26.1%
# iter 13: feat idx = 2, thres = 3.852 s = 1, alpha = 0.163, E_in(g) = 50.2% , E_in(G) = 24.9%
# iter 14: feat idx = 9, thres = -0.647 s = 1, alpha = 0.194, E_in(g) = 43.0% , E_in(G) = 24.0%
# iter 15: feat idx = 5, thres = 2.947 s = 1, alpha = 0.126, E_in(g) = 49.9% , E_in(G) = 23.3%
# iter 16: feat idx = 8, thres = -0.774 s = 1, alpha = 0.165, E_in(g) = 41.8% , E_in(G) = 22.2%
# iter 17: feat idx = 0, thres = -2.909 s = -1, alpha = 0.128, E_in(g) = 45.5% , E_in(G) = 22.5%
# iter 18: feat idx = 3, thres = 1.503 s = -1, alpha = 0.139, E_in(g) = 43.3% , E_in(G) = 21.6%
# iter 19: feat idx = 8, thres = 3.096 s = 1, alpha = 0.137, E_in(g) = 49.9% , E_in(G) = 20.4%
# iter 20: feat idx = 5, thres = -1.111 s = 1, alpha = 0.159, E_in(g) = 40.2% , E_in(G) = 21.3%
# iter 21: feat idx = 5, thres = 2.947 s = 1, alpha = 0.126, E_in(g) = 49.9% , E_in(G) = 20.3%
# iter 22: feat idx = 5, thres = 0.745 s = -1, alpha = 0.161, E_in(g) = 42.1% , E_in(G) = 20.3%
# iter 23: feat idx = 4, thres = -0.198 s = 1, alpha = 0.11, E_in(g) = 44.8% , E_in(G) = 19.5%
# iter 24: feat idx = 6, thres = 2.475 s = 1, alpha = 0.105, E_in(g) = 50.5% , E_in(G) = 20.1%
# iter 25: feat idx = 9, thres = 0.802 s = -1, alpha = 0.158, E_in(g) = 37.9% , E_in(G) = 19.1%
# iter 26: feat idx = 9, thres = 2.502 s = 1, alpha = 0.107, E_in(g) = 50.0% , E_in(G) = 19.1%
# iter 27: feat idx = 2, thres = -1.806 s = 1, alpha = 0.162, E_in(g) = 42.6% , E_in(G) = 18.1%
# iter 28: feat idx = 7, thres = 2.562 s = 1, alpha = 0.127, E_in(g) = 50.3% , E_in(G) = 17.8%
# iter 29: feat idx = 1, thres = -2.43 s = 1, alpha = 0.144, E_in(g) = 43.9% , E_in(G) = 17.5%
# iter 30: feat idx = 1, thres = -0.936 s = -1, alpha = 0.136, E_in(g) = 49.5% , E_in(G) = 16.5%
# iter 31: feat idx = 0, thres = 3.386 s = 1, alpha = 0.104, E_in(g) = 44.5% , E_in(G) = 16.1%
# iter 32: feat idx = 6, thres = 0.532 s = -1, alpha = 0.124, E_in(g) = 45.0% , E_in(G) = 15.2%
# iter 33: feat idx = 6, thres = -0.304 s = 1, alpha = 0.123, E_in(g) = 44.8% , E_in(G) = 15.8%
# iter 34: feat idx = 9, thres = 2.502 s = 1, alpha = 0.105, E_in(g) = 50.0% , E_in(G) = 14.6%
# iter 35: feat idx = 3, thres = -1.479 s = 1, alpha = 0.136, E_in(g) = 43.7% , E_in(G) = 15.7%
# iter 36: feat idx = 6, thres = 2.475 s = 1, alpha = 0.104, E_in(g) = 50.5% , E_in(G) = 14.1%
# iter 37: feat idx = 3, thres = 0.933 s = -1, alpha = 0.136, E_in(g) = 45.0% , E_in(G) = 14.9%
# iter 38: feat idx = 2, thres = -0.079 s = -1, alpha = 0.108, E_in(g) = 47.3% , E_in(G) = 13.7%
# iter 39: feat idx = 3, thres = -0.223 s = 1, alpha = 0.105, E_in(g) = 46.5% , E_in(G) = 14.2%
# iter 40: feat idx = 2, thres = -1.144 s = 1, alpha = 0.095, E_in(g) = 42.7% , E_in(G) = 14.7%
# iter 41: feat idx = 8, thres = 3.096 s = 1, alpha = 0.139, E_in(g) = 49.9% , E_in(G) = 12.8%
# iter 42: feat idx = 1, thres = -2.422 s = 1, alpha = 0.139, E_in(g) = 43.9% , E_in(G) = 13.5%
# iter 43: feat idx = 5, thres = 2.947 s = 1, alpha = 0.112, E_in(g) = 49.9% , E_in(G) = 12.5%
# iter 44: feat idx = 5, thres = -0.985 s = 1, alpha = 0.143, E_in(g) = 41.4% , E_in(G) = 13.5%
# iter 45: feat idx = 9, thres = 2.502 s = 1, alpha = 0.105, E_in(g) = 50.0% , E_in(G) = 12.0%
# iter 46: feat idx = 7, thres = -1.038 s = 1, alpha = 0.14, E_in(g) = 42.3% , E_in(G) = 13.5%
# iter 47: feat idx = 8, thres = 3.096 s = 1, alpha = 0.101, E_in(g) = 49.9% , E_in(G) = 11.9%
# iter 48: feat idx = 7, thres = 0.655 s = -1, alpha = 0.14, E_in(g) = 43.0% , E_in(G) = 13.5%
# iter 49: feat idx = 8, thres = -0.455 s = 1, alpha = 0.086, E_in(g) = 42.8% , E_in(G) = 12.8%
# iter 50: feat idx = 8, thres = 3.096 s = 1, alpha = 0.119, E_in(g) = 49.9% , E_in(G) = 12.0%
# iter 51: feat idx = 9, thres = 0.974 s = -1, alpha = 0.128, E_in(g) = 39.1% , E_in(G) = 12.3%
# iter 52: feat idx = 7, thres = 2.562 s = 1, alpha = 0.098, E_in(g) = 50.3% , E_in(G) = 11.8%
# iter 53: feat idx = 9, thres = -0.956 s = 1, alpha = 0.123, E_in(g) = 43.3% , E_in(G) = 11.7%
# iter 54: feat idx = 9, thres = 2.502 s = 1, alpha = 0.105, E_in(g) = 50.0% , E_in(G) = 11.5%
# iter 55: feat idx = 3, thres = 1.557 s = -1, alpha = 0.118, E_in(g) = 43.4% , E_in(G) = 11.8%
# iter 56: feat idx = 5, thres = 2.947 s = 1, alpha = 0.096, E_in(g) = 49.9% , E_in(G) = 10.9%
# iter 57: feat idx = 1, thres = -2.59 s = 1, alpha = 0.11, E_in(g) = 44.2% , E_in(G) = 11.5%
# iter 58: feat idx = 8, thres = 3.096 s = 1, alpha = 0.095, E_in(g) = 49.9% , E_in(G) = 10.7%
# iter 59: feat idx = 5, thres = -1.318 s = 1, alpha = 0.108, E_in(g) = 40.0% , E_in(G) = 11.5%
# iter 60: feat idx = 5, thres = 2.947 s = 1, alpha = 0.098, E_in(g) = 49.9% , E_in(G) = 10.9%
# iter 61: feat idx = 3, thres = -1.445 s = 1, alpha = 0.109, E_in(g) = 43.8% , E_in(G) = 11.7%
# iter 62: feat idx = 0, thres = -2.253 s = -1, alpha = 0.089, E_in(g) = 44.0% , E_in(G) = 10.9%
# iter 63: feat idx = 6, thres = 0.873 s = -1, alpha = 0.087, E_in(g) = 44.9% , E_in(G) = 11.1%
# iter 64: feat idx = 6, thres = 2.475 s = 1, alpha = 0.091, E_in(g) = 50.5% , E_in(G) = 10.3%
# iter 65: feat idx = 7, thres = -1.012 s = 1, alpha = 0.108, E_in(g) = 42.3% , E_in(G) = 10.7%
# iter 66: feat idx = 6, thres = 2.475 s = 1, alpha = 0.075, E_in(g) = 50.5% , E_in(G) = 10.3%
# iter 67: feat idx = 2, thres = -1.82 s = 1, alpha = 0.102, E_in(g) = 42.6% , E_in(G) = 10.8%
# iter 68: feat idx = 7, thres = 2.562 s = 1, alpha = 0.086, E_in(g) = 50.3% , E_in(G) = 10.1%
# iter 69: feat idx = 5, thres = 1.084 s = -1, alpha = 0.103, E_in(g) = 43.8% , E_in(G) = 10.6%
# iter 70: feat idx = 5, thres = 2.113 s = 1, alpha = 0.087, E_in(g) = 50.9% , E_in(G) = 9.6%
# iter 71: feat idx = 8, thres = 0.705 s = -1, alpha = 0.102, E_in(g) = 43.0% , E_in(G) = 10.3%
# iter 72: feat idx = 9, thres = -0.064 s = -1, alpha = 0.08, E_in(g) = 45.8% , E_in(G) = 10.1%
# iter 73: feat idx = 9, thres = -0.477 s = 1, alpha = 0.09, E_in(g) = 44.3% , E_in(G) = 10.4%
# iter 74: feat idx = 5, thres = 2.947 s = 1, alpha = 0.105, E_in(g) = 49.9% , E_in(G) = 9.6%
# iter 75: feat idx = 8, thres = -1.136 s = 1, alpha = 0.105, E_in(g) = 43.6% , E_in(G) = 10.1%
# iter 76: feat idx = 8, thres = 3.096 s = 1, alpha = 0.093, E_in(g) = 49.9% , E_in(G) = 9.2%
# iter 77: feat idx = 4, thres = 1.52 s = -1, alpha = 0.096, E_in(g) = 45.7% , E_in(G) = 9.9%
# iter 78: feat idx = 9, thres = 2.502 s = 1, alpha = 0.08, E_in(g) = 50.0% , E_in(G) = 9.3%
# iter 79: feat idx = 1, thres = -2.59 s = 1, alpha = 0.094, E_in(g) = 44.2% , E_in(G) = 10.1%
# iter 80: feat idx = 8, thres = 3.096 s = 1, alpha = 0.082, E_in(g) = 49.9% , E_in(G) = 9.0%
# iter 81: feat idx = 9, thres = 0.974 s = -1, alpha = 0.097, E_in(g) = 39.1% , E_in(G) = 9.8%
# iter 82: feat idx = 7, thres = 2.562 s = 1, alpha = 0.074, E_in(g) = 50.3% , E_in(G) = 9.2%
# iter 83: feat idx = 5, thres = -1.318 s = 1, alpha = 0.093, E_in(g) = 40.0% , E_in(G) = 9.6%
# iter 84: feat idx = 9, thres = 2.502 s = 1, alpha = 0.086, E_in(g) = 50.0% , E_in(G) = 9.3%
# iter 85: feat idx = 8, thres = -0.52 s = 1, alpha = 0.092, E_in(g) = 41.9% , E_in(G) = 9.6%
# iter 86: feat idx = 2, thres = -1.144 s = 1, alpha = 0.063, E_in(g) = 42.7% , E_in(G) = 9.7%
# iter 87: feat idx = 5, thres = 2.947 s = 1, alpha = 0.086, E_in(g) = 49.9% , E_in(G) = 9.8%
# iter 88: feat idx = 2, thres = 0.651 s = -1, alpha = 0.099, E_in(g) = 42.7% , E_in(G) = 9.1%
# iter 89: feat idx = 3, thres = -0.898 s = 1, alpha = 0.072, E_in(g) = 45.1% , E_in(G) = 9.4%
# iter 90: feat idx = 2, thres = 3.852 s = 1, alpha = 0.074, E_in(g) = 50.2% , E_in(G) = 9.2%
# iter 91: feat idx = 3, thres = 0.933 s = -1, alpha = 0.1, E_in(g) = 45.0% , E_in(G) = 8.9%
# iter 92: feat idx = 5, thres = -0.294 s = 1, alpha = 0.061, E_in(g) = 51.2% , E_in(G) = 9.3%
# iter 93: feat idx = 0, thres = 2.584 s = 1, alpha = 0.082, E_in(g) = 43.1% , E_in(G) = 8.9%
# iter 94: feat idx = 0, thres = -1.003 s = -1, alpha = 0.083, E_in(g) = 46.0% , E_in(G) = 9.0%
# iter 95: feat idx = 6, thres = -0.777 s = 1, alpha = 0.078, E_in(g) = 44.5% , E_in(G) = 9.0%
# iter 96: feat idx = 8, thres = 3.096 s = 1, alpha = 0.063, E_in(g) = 49.9% , E_in(G) = 9.1%
# iter 97: feat idx = 5, thres = -1.123 s = 1, alpha = 0.085, E_in(g) = 40.2% , E_in(G) = 9.5%
# iter 98: feat idx = 5, thres = 3.308 s = 1, alpha = 0.072, E_in(g) = 49.9% , E_in(G) = 8.9%
# iter 99: feat idx = 5, thres = 0.475 s = -1, alpha = 0.086, E_in(g) = 41.6% , E_in(G) = 9.9%
# iter 100: feat idx = 5, thres = 0.186 s = 1, alpha = 0.093, E_in(g) = 53.3% , E_in(G) = 9.0%
# iter 101: feat idx = 1, thres = -1.65 s = 1, alpha = 0.073, E_in(g) = 46.9% , E_in(G) = 9.2%
# iter 102: feat idx = 1, thres = -0.738 s = -1, alpha = 0.084, E_in(g) = 49.2% , E_in(G) = 8.6%
# iter 103: feat idx = 5, thres = 0.372 s = -1, alpha = 0.064, E_in(g) = 42.6% , E_in(G) = 9.3%
# iter 104: feat idx = 5, thres = 2.113 s = 1, alpha = 0.065, E_in(g) = 50.9% , E_in(G) = 8.6%
# iter 105: feat idx = 8, thres = 1.623 s = -1, alpha = 0.085, E_in(g) = 45.6% , E_in(G) = 9.4%
# iter 106: feat idx = 9, thres = 2.502 s = 1, alpha = 0.076, E_in(g) = 50.0% , E_in(G) = 8.4%
# iter 107: feat idx = 1, thres = -2.807 s = 1, alpha = 0.083, E_in(g) = 45.2% , E_in(G) = 9.4%
# iter 108: feat idx = 8, thres = 3.096 s = 1, alpha = 0.076, E_in(g) = 49.9% , E_in(G) = 8.4%
# iter 109: feat idx = 3, thres = -1.479 s = 1, alpha = 0.084, E_in(g) = 43.7% , E_in(G) = 9.5%
# iter 110: feat idx = 1, thres = 1.244 s = 1, alpha = 0.066, E_in(g) = 48.4% , E_in(G) = 8.9%
# iter 111: feat idx = 6, thres = 0.532 s = -1, alpha = 0.074, E_in(g) = 45.0% , E_in(G) = 8.3%
# iter 112: feat idx = 6, thres = 2.475 s = 1, alpha = 0.066, E_in(g) = 50.5% , E_in(G) = 8.2%
# iter 113: feat idx = 3, thres = 1.503 s = -1, alpha = 0.083, E_in(g) = 43.3% , E_in(G) = 8.8%
# iter 114: feat idx = 8, thres = 3.096 s = 1, alpha = 0.067, E_in(g) = 49.9% , E_in(G) = 8.2%
# iter 115: feat idx = 2, thres = -1.82 s = 1, alpha = 0.08, E_in(g) = 42.6% , E_in(G) = 8.6%
# iter 116: feat idx = 4, thres = 0.726 s = 1, alpha = 0.066, E_in(g) = 50.6% , E_in(G) = 8.2%
# iter 117: feat idx = 6, thres = -0.496 s = 1, alpha = 0.062, E_in(g) = 45.2% , E_in(G) = 8.8%
# iter 118: feat idx = 4, thres = -1.126 s = -1, alpha = 0.067, E_in(g) = 53.7% , E_in(G) = 8.5%
# iter 119: feat idx = 6, thres = 1.086 s = -1, alpha = 0.071, E_in(g) = 44.6% , E_in(G) = 8.5%
# iter 120: feat idx = 5, thres = 3.308 s = 1, alpha = 0.066, E_in(g) = 49.9% , E_in(G) = 8.3%
# iter 121: feat idx = 9, thres = 1.13 s = -1, alpha = 0.082, E_in(g) = 40.8% , E_in(G) = 8.0%
# iter 122: feat idx = 8, thres = 3.096 s = 1, alpha = 0.066, E_in(g) = 49.9% , E_in(G) = 8.2%
# iter 123: feat idx = 9, thres = -0.956 s = 1, alpha = 0.081, E_in(g) = 43.3% , E_in(G) = 7.9%
# iter 124: feat idx = 5, thres = 3.308 s = 1, alpha = 0.07, E_in(g) = 49.9% , E_in(G) = 8.5%
# iter 125: feat idx = 4, thres = -1.563 s = 1, alpha = 0.077, E_in(g) = 46.2% , E_in(G) = 7.9%
# iter 126: feat idx = 8, thres = 3.096 s = 1, alpha = 0.064, E_in(g) = 49.9% , E_in(G) = 8.0%
# iter 127: feat idx = 4, thres = 1.414 s = -1, alpha = 0.077, E_in(g) = 45.7% , E_in(G) = 7.7%
# iter 128: feat idx = 9, thres = 2.502 s = 1, alpha = 0.064, E_in(g) = 50.0% , E_in(G) = 8.1%
# iter 129: feat idx = 7, thres = 1.079 s = -1, alpha = 0.074, E_in(g) = 44.2% , E_in(G) = 7.5%
# iter 130: feat idx = 9, thres = -0.064 s = -1, alpha = 0.064, E_in(g) = 45.8% , E_in(G) = 8.0%
# iter 131: feat idx = 9, thres = -0.467 s = 1, alpha = 0.065, E_in(g) = 44.4% , E_in(G) = 7.8%
# iter 132: feat idx = 7, thres = 2.562 s = 1, alpha = 0.083, E_in(g) = 50.3% , E_in(G) = 8.1%
# iter 133: feat idx = 3, thres = -1.358 s = 1, alpha = 0.077, E_in(g) = 44.2% , E_in(G) = 7.8%
# iter 134: feat idx = 5, thres = 2.947 s = 1, alpha = 0.057, E_in(g) = 49.9% , E_in(G) = 7.8%
# iter 135: feat idx = 7, thres = -0.55 s = 1, alpha = 0.08, E_in(g) = 42.6% , E_in(G) = 7.9%
# iter 136: feat idx = 1, thres = -1.755 s = 1, alpha = 0.06, E_in(g) = 46.4% , E_in(G) = 7.7%
# iter 137: feat idx = 1, thres = -0.907 s = -1, alpha = 0.068, E_in(g) = 49.5% , E_in(G) = 7.6%
# iter 138: feat idx = 1, thres = -1.58 s = 1, alpha = 0.053, E_in(g) = 47.0% , E_in(G) = 7.6%
# iter 139: feat idx = 8, thres = 3.096 s = 1, alpha = 0.073, E_in(g) = 49.9% , E_in(G) = 8.0%
# iter 140: feat idx = 8, thres = -1.136 s = 1, alpha = 0.08, E_in(g) = 43.6% , E_in(G) = 7.7%
# iter 141: feat idx = 5, thres = 3.308 s = 1, alpha = 0.072, E_in(g) = 49.9% , E_in(G) = 8.0%
# iter 142: feat idx = 8, thres = 1.623 s = -1, alpha = 0.076, E_in(g) = 45.6% , E_in(G) = 7.4%
# iter 143: feat idx = 5, thres = 2.947 s = 1, alpha = 0.071, E_in(g) = 49.9% , E_in(G) = 7.7%
# iter 144: feat idx = 2, thres = -1.144 s = 1, alpha = 0.077, E_in(g) = 42.7% , E_in(G) = 7.6%
# iter 145: feat idx = 2, thres = -0.215 s = -1, alpha = 0.081, E_in(g) = 48.9% , E_in(G) = 7.6%
# iter 146: feat idx = 5, thres = 0.186 s = 1, alpha = 0.056, E_in(g) = 53.3% , E_in(G) = 7.2%
# iter 147: feat idx = 5, thres = 1.084 s = -1, alpha = 0.061, E_in(g) = 43.8% , E_in(G) = 7.4%
# iter 148: feat idx = 8, thres = 3.096 s = 1, alpha = 0.076, E_in(g) = 49.9% , E_in(G) = 7.0%
# iter 149: feat idx = 5, thres = -1.308 s = 1, alpha = 0.073, E_in(g) = 40.0% , E_in(G) = 7.4%
# iter 150: feat idx = 7, thres = -2.386 s = -1, alpha = 0.068, E_in(g) = 50.4% , E_in(G) = 7.0%
# iter 151: feat idx = 1, thres = 1.97 s = -1, alpha = 0.069, E_in(g) = 48.6% , E_in(G) = 7.3%
# iter 152: feat idx = 4, thres = -0.256 s = 1, alpha = 0.056, E_in(g) = 44.5% , E_in(G) = 7.3%
# iter 153: feat idx = 4, thres = -1.148 s = -1, alpha = 0.061, E_in(g) = 53.7% , E_in(G) = 7.1%
# iter 154: feat idx = 1, thres = -2.59 s = 1, alpha = 0.066, E_in(g) = 44.2% , E_in(G) = 7.4%
# iter 155: feat idx = 0, thres = 4.001 s = 1, alpha = 0.068, E_in(g) = 46.8% , E_in(G) = 7.1%
# iter 156: feat idx = 9, thres = 1.13 s = -1, alpha = 0.065, E_in(g) = 40.8% , E_in(G) = 7.2%
# iter 157: feat idx = 3, thres = -2.709 s = -1, alpha = 0.063, E_in(g) = 50.4% , E_in(G) = 7.2%
# iter 158: feat idx = 2, thres = -1.82 s = 1, alpha = 0.069, E_in(g) = 42.6% , E_in(G) = 7.4%
# iter 159: feat idx = 5, thres = 2.947 s = 1, alpha = 0.057, E_in(g) = 49.9% , E_in(G) = 7.1%
# iter 160: feat idx = 7, thres = -1.264 s = 1, alpha = 0.07, E_in(g) = 43.5% , E_in(G) = 7.2%
# iter 161: feat idx = 5, thres = 3.308 s = 1, alpha = 0.055, E_in(g) = 49.9% , E_in(G) = 7.1%
# iter 162: feat idx = 2, thres = 2.052 s = -1, alpha = 0.07, E_in(g) = 46.7% , E_in(G) = 7.4%
# iter 163: feat idx = 2, thres = 3.852 s = 1, alpha = 0.06, E_in(g) = 50.2% , E_in(G) = 6.8%
# iter 164: feat idx = 8, thres = 1.623 s = -1, alpha = 0.067, E_in(g) = 45.6% , E_in(G) = 7.0%
# iter 165: feat idx = 8, thres = 3.096 s = 1, alpha = 0.063, E_in(g) = 49.9% , E_in(G) = 6.5%
# iter 166: feat idx = 1, thres = -2.807 s = 1, alpha = 0.067, E_in(g) = 45.2% , E_in(G) = 7.2%
# iter 167: feat idx = 5, thres = 3.308 s = 1, alpha = 0.062, E_in(g) = 49.9% , E_in(G) = 6.4%
# iter 168: feat idx = 4, thres = 1.52 s = -1, alpha = 0.067, E_in(g) = 45.7% , E_in(G) = 7.2%
# iter 169: feat idx = 8, thres = 3.096 s = 1, alpha = 0.057, E_in(g) = 49.9% , E_in(G) = 6.5%
# iter 170: feat idx = 4, thres = -1.401 s = 1, alpha = 0.067, E_in(g) = 45.2% , E_in(G) = 7.5%
# iter 171: feat idx = 4, thres = -1.148 s = -1, alpha = 0.056, E_in(g) = 53.7% , E_in(G) = 6.8%
# iter 172: feat idx = 7, thres = 0.259 s = -1, alpha = 0.061, E_in(g) = 46.8% , E_in(G) = 6.9%
# iter 173: feat idx = 7, thres = 0.48 s = 1, alpha = 0.054, E_in(g) = 54.7% , E_in(G) = 6.5%
# iter 174: feat idx = 5, thres = -1.318 s = 1, alpha = 0.06, E_in(g) = 40.0% , E_in(G) = 7.3%
# iter 175: feat idx = 5, thres = 3.308 s = 1, alpha = 0.062, E_in(g) = 49.9% , E_in(G) = 6.5%
# iter 176: feat idx = 8, thres = -1.176 s = 1, alpha = 0.065, E_in(g) = 43.7% , E_in(G) = 7.2%
# iter 177: feat idx = 5, thres = 2.947 s = 1, alpha = 0.059, E_in(g) = 49.9% , E_in(G) = 6.5%
# iter 178: feat idx = 9, thres = -1.09 s = 1, alpha = 0.064, E_in(g) = 44.1% , E_in(G) = 7.1%
# iter 179: feat idx = 9, thres = -0.064 s = -1, alpha = 0.062, E_in(g) = 45.8% , E_in(G) = 6.9%
# iter 180: feat idx = 4, thres = 0.726 s = 1, alpha = 0.053, E_in(g) = 50.6% , E_in(G) = 6.6%
# iter 181: feat idx = 9, thres = -0.449 s = 1, alpha = 0.061, E_in(g) = 44.7% , E_in(G) = 7.0%
# iter 182: feat idx = 8, thres = 0.022 s = -1, alpha = 0.051, E_in(g) = 49.4% , E_in(G) = 6.7%
# iter 183: feat idx = 8, thres = 0.39 s = 1, alpha = 0.062, E_in(g) = 53.6% , E_in(G) = 6.7%
# iter 184: feat idx = 8, thres = 0.608 s = -1, alpha = 0.062, E_in(g) = 43.9% , E_in(G) = 6.5%
# iter 185: feat idx = 6, thres = 2.475 s = 1, alpha = 0.062, E_in(g) = 50.5% , E_in(G) = 6.3%
# iter 186: feat idx = 8, thres = -0.455 s = 1, alpha = 0.072, E_in(g) = 42.8% , E_in(G) = 6.4%
# iter 187: feat idx = 8, thres = 0.014 s = -1, alpha = 0.051, E_in(g) = 49.3% , E_in(G) = 6.4%
# iter 188: feat idx = 3, thres = -0.302 s = 1, alpha = 0.05, E_in(g) = 46.6% , E_in(G) = 6.4%
# iter 189: feat idx = 3, thres = 0.92 s = -1, alpha = 0.05, E_in(g) = 45.0% , E_in(G) = 6.6%
# iter 190: feat idx = 8, thres = 3.096 s = 1, alpha = 0.07, E_in(g) = 49.9% , E_in(G) = 6.2%
# iter 191: feat idx = 2, thres = -1.144 s = 1, alpha = 0.068, E_in(g) = 42.7% , E_in(G) = 6.8%
# iter 192: feat idx = 2, thres = -0.465 s = -1, alpha = 0.051, E_in(g) = 50.7% , E_in(G) = 6.4%
# iter 193: feat idx = 1, thres = -1.804 s = 1, alpha = 0.051, E_in(g) = 46.3% , E_in(G) = 6.6%
# iter 194: feat idx = 7, thres = -2.386 s = -1, alpha = 0.056, E_in(g) = 50.4% , E_in(G) = 6.5%
# iter 195: feat idx = 6, thres = 0.885 s = -1, alpha = 0.066, E_in(g) = 44.8% , E_in(G) = 6.6%
# iter 196: feat idx = 2, thres = -0.724 s = 1, alpha = 0.048, E_in(g) = 44.8% , E_in(G) = 6.6%
# iter 197: feat idx = 8, thres = 3.096 s = 1, alpha = 0.059, E_in(g) = 49.9% , E_in(G) = 6.7%
# iter 198: feat idx = 9, thres = 1.215 s = -1, alpha = 0.064, E_in(g) = 41.7% , E_in(G) = 6.6%
# iter 199: feat idx = 9, thres = 2.502 s = 1, alpha = 0.054, E_in(g) = 50.0% , E_in(G) = 6.8%
# iter 200: feat idx = 6, thres = -0.496 s = 1, alpha = 0.065, E_in(g) = 45.2% , E_in(G) = 6.7%
# iter 201: feat idx = 6, thres = -0.964 s = -1, alpha = 0.052, E_in(g) = 54.2% , E_in(G) = 6.6%
# iter 202: feat idx = 3, thres = -1.68 s = 1, alpha = 0.074, E_in(g) = 44.4% , E_in(G) = 6.9%
# iter 203: feat idx = 5, thres = 2.947 s = 1, alpha = 0.055, E_in(g) = 49.9% , E_in(G) = 6.4%
# iter 204: feat idx = 4, thres = -1.563 s = 1, alpha = 0.064, E_in(g) = 46.2% , E_in(G) = 6.8%
# iter 205: feat idx = 5, thres = 3.308 s = 1, alpha = 0.054, E_in(g) = 49.9% , E_in(G) = 6.4%
# iter 206: feat idx = 3, thres = 1.503 s = -1, alpha = 0.065, E_in(g) = 43.3% , E_in(G) = 6.6%
# iter 207: feat idx = 8, thres = 0.337 s = 1, alpha = 0.055, E_in(g) = 53.3% , E_in(G) = 6.2%
# iter 208: feat idx = 8, thres = 0.705 s = -1, alpha = 0.051, E_in(g) = 43.0% , E_in(G) = 6.4%
# iter 209: feat idx = 8, thres = 3.096 s = 1, alpha = 0.067, E_in(g) = 49.9% , E_in(G) = 5.8%
# iter 210: feat idx = 5, thres = -1.308 s = 1, alpha = 0.062, E_in(g) = 40.0% , E_in(G) = 6.4%
# iter 211: feat idx = 5, thres = 3.308 s = 1, alpha = 0.058, E_in(g) = 49.9% , E_in(G) = 5.9%
# iter 212: feat idx = 5, thres = 1.084 s = -1, alpha = 0.062, E_in(g) = 43.8% , E_in(G) = 6.4%
# iter 213: feat idx = 5, thres = 1.856 s = 1, alpha = 0.056, E_in(g) = 51.6% , E_in(G) = 5.9%
# iter 214: feat idx = 7, thres = 1.079 s = -1, alpha = 0.062, E_in(g) = 44.2% , E_in(G) = 6.2%
# iter 215: feat idx = 7, thres = -0.195 s = 1, alpha = 0.051, E_in(g) = 46.2% , E_in(G) = 5.9%
# iter 216: feat idx = 7, thres = 2.562 s = 1, alpha = 0.054, E_in(g) = 50.3% , E_in(G) = 5.7%
# iter 217: feat idx = 4, thres = 1.289 s = -1, alpha = 0.06, E_in(g) = 46.4% , E_in(G) = 6.0%
# iter 218: feat idx = 7, thres = -0.376 s = -1, alpha = 0.049, E_in(g) = 54.4% , E_in(G) = 6.1%
# iter 219: feat idx = 7, thres = -1.012 s = 1, alpha = 0.042, E_in(g) = 42.3% , E_in(G) = 6.2%
# iter 220: feat idx = 8, thres = 3.096 s = 1, alpha = 0.062, E_in(g) = 49.9% , E_in(G) = 5.9%
# iter 221: feat idx = 1, thres = -2.807 s = 1, alpha = 0.059, E_in(g) = 45.2% , E_in(G) = 6.0%
# iter 222: feat idx = 5, thres = 3.308 s = 1, alpha = 0.055, E_in(g) = 49.9% , E_in(G) = 5.9%
# iter 223: feat idx = 5, thres = -1.12 s = 1, alpha = 0.058, E_in(g) = 40.2% , E_in(G) = 6.2%
# iter 224: feat idx = 1, thres = -0.936 s = -1, alpha = 0.052, E_in(g) = 49.5% , E_in(G) = 6.3%
# iter 225: feat idx = 1, thres = -1.65 s = 1, alpha = 0.05, E_in(g) = 46.9% , E_in(G) = 6.4%
# iter 226: feat idx = 8, thres = 3.096 s = 1, alpha = 0.062, E_in(g) = 49.9% , E_in(G) = 6.0%
# iter 227: feat idx = 2, thres = 2.052 s = -1, alpha = 0.059, E_in(g) = 46.7% , E_in(G) = 6.0%
# iter 228: feat idx = 2, thres = 3.852 s = 1, alpha = 0.051, E_in(g) = 50.2% , E_in(G) = 5.8%
# iter 229: feat idx = 3, thres = -1.358 s = 1, alpha = 0.059, E_in(g) = 44.2% , E_in(G) = 6.1%
# iter 230: feat idx = 3, thres = -0.69 s = -1, alpha = 0.048, E_in(g) = 53.3% , E_in(G) = 5.8%
# iter 231: feat idx = 3, thres = -0.481 s = 1, alpha = 0.052, E_in(g) = 45.8% , E_in(G) = 5.9%
# iter 232: feat idx = 3, thres = -0.69 s = -1, alpha = 0.043, E_in(g) = 53.3% , E_in(G) = 5.7%
# iter 233: feat idx = 2, thres = -2.073 s = 1, alpha = 0.043, E_in(g) = 44.0% , E_in(G) = 5.9%
# iter 234: feat idx = 9, thres = 2.502 s = 1, alpha = 0.059, E_in(g) = 50.0% , E_in(G) = 5.8%
# iter 235: feat idx = 1, thres = 3.45 s = -1, alpha = 0.059, E_in(g) = 48.0% , E_in(G) = 5.8%
# iter 236: feat idx = 8, thres = 3.096 s = 1, alpha = 0.051, E_in(g) = 49.9% , E_in(G) = 5.8%
# iter 237: feat idx = 8, thres = 1.623 s = -1, alpha = 0.058, E_in(g) = 45.6% , E_in(G) = 5.8%
# iter 238: feat idx = 5, thres = 3.308 s = 1, alpha = 0.055, E_in(g) = 49.9% , E_in(G) = 5.8%
# iter 239: feat idx = 9, thres = -1.09 s = 1, alpha = 0.058, E_in(g) = 44.1% , E_in(G) = 5.8%
# iter 240: feat idx = 1, thres = 2.3 s = 1, alpha = 0.052, E_in(g) = 50.9% , E_in(G) = 5.7%
# iter 241: feat idx = 3, thres = -0.898 s = 1, alpha = 0.048, E_in(g) = 45.1% , E_in(G) = 6.0%
# iter 242: feat idx = 9, thres = -0.064 s = -1, alpha = 0.045, E_in(g) = 45.8% , E_in(G) = 5.8%
# iter 243: feat idx = 9, thres = -0.477 s = 1, alpha = 0.045, E_in(g) = 44.3% , E_in(G) = 6.0%
# iter 244: feat idx = 9, thres = -0.803 s = -1, alpha = 0.058, E_in(g) = 56.3% , E_in(G) = 5.8%
# iter 245: feat idx = 8, thres = -0.805 s = 1, alpha = 0.049, E_in(g) = 41.8% , E_in(G) = 5.9%
# iter 246: feat idx = 4, thres = -1.155 s = -1, alpha = 0.05, E_in(g) = 53.7% , E_in(G) = 5.9%
# iter 247: feat idx = 4, thres = -0.256 s = 1, alpha = 0.052, E_in(g) = 44.5% , E_in(G) = 5.8%
# iter 248: feat idx = 4, thres = 0.141 s = -1, alpha = 0.05, E_in(g) = 50.8% , E_in(G) = 6.1%
# iter 249: feat idx = 4, thres = 0.726 s = 1, alpha = 0.048, E_in(g) = 50.6% , E_in(G) = 5.7%
# iter 250: feat idx = 1, thres = 3.45 s = -1, alpha = 0.055, E_in(g) = 48.0% , E_in(G) = 6.2%
# iter 251: feat idx = 0, thres = -1.003 s = -1, alpha = 0.053, E_in(g) = 46.0% , E_in(G) = 6.0%
# iter 252: feat idx = 0, thres = 0.239 s = 1, alpha = 0.071, E_in(g) = 48.5% , E_in(G) = 5.9%
# iter 253: feat idx = 0, thres = -1.003 s = -1, alpha = 0.052, E_in(g) = 46.0% , E_in(G) = 6.0%
# iter 254: feat idx = 7, thres = -0.55 s = 1, alpha = 0.047, E_in(g) = 42.6% , E_in(G) = 5.8%
# iter 255: feat idx = 0, thres = 1.859 s = 1, alpha = 0.047, E_in(g) = 44.3% , E_in(G) = 6.0%
# iter 256: feat idx = 5, thres = 0.186 s = 1, alpha = 0.045, E_in(g) = 53.3% , E_in(G) = 5.6%
# iter 257: feat idx = 5, thres = 0.372 s = -1, alpha = 0.06, E_in(g) = 42.6% , E_in(G) = 6.0%
# iter 258: feat idx = 5, thres = 0.186 s = 1, alpha = 0.052, E_in(g) = 53.3% , E_in(G) = 5.7%
# iter 259: feat idx = 5, thres = 0.372 s = -1, alpha = 0.045, E_in(g) = 42.6% , E_in(G) = 6.0%
# iter 260: feat idx = 6, thres = 2.475 s = 1, alpha = 0.051, E_in(g) = 50.5% , E_in(G) = 5.9%
# iter 261: feat idx = 9, thres = 1.105 s = -1, alpha = 0.063, E_in(g) = 40.9% , E_in(G) = 6.0%
# iter 262: feat idx = 7, thres = -2.386 s = -1, alpha = 0.051, E_in(g) = 50.4% , E_in(G) = 6.0%
# iter 263: feat idx = 4, thres = -1.563 s = 1, alpha = 0.057, E_in(g) = 46.2% , E_in(G) = 5.9%
# iter 264: feat idx = 9, thres = 2.502 s = 1, alpha = 0.049, E_in(g) = 50.0% , E_in(G) = 5.9%
# iter 265: feat idx = 9, thres = -1.09 s = 1, alpha = 0.057, E_in(g) = 44.1% , E_in(G) = 5.8%
# iter 266: feat idx = 5, thres = 2.947 s = 1, alpha = 0.052, E_in(g) = 49.9% , E_in(G) = 5.9%
# iter 267: feat idx = 0, thres = 2.979 s = -1, alpha = 0.057, E_in(g) = 54.9% , E_in(G) = 5.5%
# iter 268: feat idx = 0, thres = 2.584 s = 1, alpha = 0.052, E_in(g) = 43.1% , E_in(G) = 5.9%
# iter 269: feat idx = 8, thres = -0.455 s = 1, alpha = 0.053, E_in(g) = 42.8% , E_in(G) = 5.7%
# iter 270: feat idx = 8, thres = 0.022 s = -1, alpha = 0.045, E_in(g) = 49.4% , E_in(G) = 5.9%
# iter 271: feat idx = 8, thres = -0.229 s = 1, alpha = 0.046, E_in(g) = 45.9% , E_in(G) = 5.7%
# iter 272: feat idx = 4, thres = -1.268 s = -1, alpha = 0.05, E_in(g) = 53.6% , E_in(G) = 5.8%
# iter 273: feat idx = 6, thres = 0.459 s = -1, alpha = 0.053, E_in(g) = 45.7% , E_in(G) = 5.5%
# iter 274: feat idx = 6, thres = -0.496 s = 1, alpha = 0.05, E_in(g) = 45.2% , E_in(G) = 5.7%
# iter 275: feat idx = 6, thres = -0.964 s = -1, alpha = 0.052, E_in(g) = 54.2% , E_in(G) = 5.6%
# iter 276: feat idx = 6, thres = -0.777 s = 1, alpha = 0.05, E_in(g) = 44.5% , E_in(G) = 5.7%
# iter 277: feat idx = 6, thres = -0.24 s = -1, alpha = 0.05, E_in(g) = 53.4% , E_in(G) = 5.5%
# iter 278: feat idx = 6, thres = 0.052 s = 1, alpha = 0.054, E_in(g) = 48.9% , E_in(G) = 5.6%
# iter 279: feat idx = 0, thres = -1.27 s = -1, alpha = 0.046, E_in(g) = 45.6% , E_in(G) = 5.4%
# iter 280: feat idx = 3, thres = 0.933 s = -1, alpha = 0.054, E_in(g) = 45.0% , E_in(G) = 5.8%
# iter 281: feat idx = 6, thres = -0.153 s = -1, alpha = 0.047, E_in(g) = 52.6% , E_in(G) = 5.3%
# iter 282: feat idx = 8, thres = -0.141 s = -1, alpha = 0.043, E_in(g) = 51.8% , E_in(G) = 5.5%
# iter 283: feat idx = 8, thres = -0.229 s = 1, alpha = 0.043, E_in(g) = 45.9% , E_in(G) = 5.3%
# iter 284: feat idx = 1, thres = -0.544 s = -1, alpha = 0.041, E_in(g) = 49.5% , E_in(G) = 5.6%
# iter 285: feat idx = 1, thres = 0.156 s = 1, alpha = 0.059, E_in(g) = 49.2% , E_in(G) = 5.3%
# iter 286: feat idx = 1, thres = 0.398 s = -1, alpha = 0.045, E_in(g) = 50.1% , E_in(G) = 5.4%
# iter 287: feat idx = 1, thres = 0.95 s = 1, alpha = 0.048, E_in(g) = 48.5% , E_in(G) = 5.3%
# iter 288: feat idx = 8, thres = 0.608 s = -1, alpha = 0.047, E_in(g) = 43.9% , E_in(G) = 5.6%
# iter 289: feat idx = 7, thres = -2.386 s = -1, alpha = 0.048, E_in(g) = 50.4% , E_in(G) = 5.3%
# iter 290: feat idx = 1, thres = -2.59 s = 1, alpha = 0.059, E_in(g) = 44.2% , E_in(G) = 5.7%
# iter 291: feat idx = 7, thres = 2.562 s = 1, alpha = 0.054, E_in(g) = 50.3% , E_in(G) = 5.3%
# iter 292: feat idx = 3, thres = -1.344 s = 1, alpha = 0.059, E_in(g) = 44.2% , E_in(G) = 5.7%
# iter 293: feat idx = 5, thres = 1.856 s = 1, alpha = 0.043, E_in(g) = 51.6% , E_in(G) = 5.5%
# iter 294: feat idx = 5, thres = 1.225 s = -1, alpha = 0.053, E_in(g) = 44.4% , E_in(G) = 5.5%
# iter 295: feat idx = 5, thres = 1.856 s = 1, alpha = 0.049, E_in(g) = 51.6% , E_in(G) = 5.5%
# iter 296: feat idx = 5, thres = -1.308 s = 1, alpha = 0.054, E_in(g) = 40.0% , E_in(G) = 5.5%
# iter 297: feat idx = 5, thres = 2.947 s = 1, alpha = 0.056, E_in(g) = 49.9% , E_in(G) = 5.5%
# iter 298: feat idx = 4, thres = -1.401 s = 1, alpha = 0.056, E_in(g) = 45.2% , E_in(G) = 5.4%
# iter 299: feat idx = 4, thres = -1.148 s = -1, alpha = 0.048, E_in(g) = 53.7% , E_in(G) = 5.6%
# iter 300: feat idx = 6, thres = -0.438 s = 1, alpha = 0.049, E_in(g) = 44.9% , E_in(G) = 5.4%
# iter 301: feat idx = 1, thres = -0.544 s = -1, alpha = 0.044, E_in(g) = 49.5% , E_in(G) = 5.7%
# iter 302: feat idx = 1, thres = -1.65 s = 1, alpha = 0.048, E_in(g) = 46.9% , E_in(G) = 5.5%
# iter 303: feat idx = 6, thres = -0.964 s = -1, alpha = 0.053, E_in(g) = 54.2% , E_in(G) = 5.6%
# iter 304: feat idx = 9, thres = 1.13 s = -1, alpha = 0.049, E_in(g) = 40.8% , E_in(G) = 5.5%
# iter 305: feat idx = 9, thres = 2.502 s = 1, alpha = 0.051, E_in(g) = 50.0% , E_in(G) = 5.5%
# iter 306: feat idx = 2, thres = -2.073 s = 1, alpha = 0.058, E_in(g) = 44.0% , E_in(G) = 5.5%
# iter 307: feat idx = 5, thres = 2.947 s = 1, alpha = 0.053, E_in(g) = 49.9% , E_in(G) = 5.5%
# iter 308: feat idx = 7, thres = -1.264 s = 1, alpha = 0.057, E_in(g) = 43.5% , E_in(G) = 5.5%
# iter 309: feat idx = 7, thres = -2.386 s = -1, alpha = 0.047, E_in(g) = 50.4% , E_in(G) = 5.4%
# iter 310: feat idx = 7, thres = 1.079 s = -1, alpha = 0.058, E_in(g) = 44.2% , E_in(G) = 5.5%
# iter 311: feat idx = 7, thres = 1.68 s = 1, alpha = 0.046, E_in(g) = 52.6% , E_in(G) = 5.5%
# iter 312: feat idx = 8, thres = -1.517 s = 1, alpha = 0.054, E_in(g) = 46.3% , E_in(G) = 5.5%
# iter 313: feat idx = 8, thres = 3.096 s = 1, alpha = 0.054, E_in(g) = 49.9% , E_in(G) = 5.4%
# iter 314: feat idx = 8, thres = 1.623 s = -1, alpha = 0.057, E_in(g) = 45.6% , E_in(G) = 5.5%
# iter 315: feat idx = 8, thres = 3.096 s = 1, alpha = 0.054, E_in(g) = 49.9% , E_in(G) = 5.5%
# iter 316: feat idx = 1, thres = 3.45 s = -1, alpha = 0.056, E_in(g) = 48.0% , E_in(G) = 5.6%
# iter 317: feat idx = 5, thres = 2.947 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 5.5%
# iter 318: feat idx = 6, thres = -1.71 s = 1, alpha = 0.055, E_in(g) = 46.5% , E_in(G) = 5.5%
# iter 319: feat idx = 8, thres = 3.096 s = 1, alpha = 0.052, E_in(g) = 49.9% , E_in(G) = 5.4%
# iter 320: feat idx = 2, thres = 2.052 s = -1, alpha = 0.054, E_in(g) = 46.7% , E_in(G) = 5.6%
# iter 321: feat idx = 2, thres = 1.592 s = 1, alpha = 0.049, E_in(g) = 54.3% , E_in(G) = 5.5%
# iter 322: feat idx = 2, thres = 1.452 s = -1, alpha = 0.049, E_in(g) = 44.8% , E_in(G) = 5.6%
# iter 323: feat idx = 2, thres = 1.014 s = 1, alpha = 0.048, E_in(g) = 55.5% , E_in(G) = 5.4%
# iter 324: feat idx = 4, thres = -0.256 s = 1, alpha = 0.05, E_in(g) = 44.5% , E_in(G) = 5.3%
# iter 325: feat idx = 4, thres = 0.589 s = -1, alpha = 0.051, E_in(g) = 49.0% , E_in(G) = 5.4%
# iter 326: feat idx = 4, thres = 0.726 s = 1, alpha = 0.06, E_in(g) = 50.6% , E_in(G) = 5.3%
# iter 327: feat idx = 4, thres = 0.589 s = -1, alpha = 0.053, E_in(g) = 49.0% , E_in(G) = 5.4%
# iter 328: feat idx = 4, thres = 0.726 s = 1, alpha = 0.047, E_in(g) = 50.6% , E_in(G) = 5.3%
# iter 329: feat idx = 4, thres = 1.52 s = -1, alpha = 0.053, E_in(g) = 45.7% , E_in(G) = 5.3%
# iter 330: feat idx = 8, thres = 3.096 s = 1, alpha = 0.055, E_in(g) = 49.9% , E_in(G) = 5.2%
# iter 331: feat idx = 1, thres = -2.807 s = 1, alpha = 0.055, E_in(g) = 45.2% , E_in(G) = 5.3%
# iter 332: feat idx = 7, thres = 2.562 s = 1, alpha = 0.052, E_in(g) = 50.3% , E_in(G) = 5.2%
# iter 333: feat idx = 9, thres = 0.478 s = -1, alpha = 0.056, E_in(g) = 37.8% , E_in(G) = 5.3%
# iter 334: feat idx = 9, thres = -0.477 s = 1, alpha = 0.049, E_in(g) = 44.3% , E_in(G) = 5.7%
# iter 335: feat idx = 2, thres = 4.717 s = 1, alpha = 0.05, E_in(g) = 50.2% , E_in(G) = 5.5%
# iter 336: feat idx = 5, thres = -1.247 s = 1, alpha = 0.056, E_in(g) = 39.6% , E_in(G) = 5.7%
# iter 337: feat idx = 5, thres = 2.947 s = 1, alpha = 0.051, E_in(g) = 49.9% , E_in(G) = 5.6%
# iter 338: feat idx = 5, thres = 1.126 s = -1, alpha = 0.054, E_in(g) = 44.0% , E_in(G) = 5.7%
# iter 339: feat idx = 5, thres = 1.856 s = 1, alpha = 0.044, E_in(g) = 51.6% , E_in(G) = 5.6%
# iter 340: feat idx = 8, thres = -1.517 s = 1, alpha = 0.051, E_in(g) = 46.3% , E_in(G) = 5.8%
# iter 341: feat idx = 5, thres = 3.308 s = 1, alpha = 0.052, E_in(g) = 49.9% , E_in(G) = 5.5%
# iter 342: feat idx = 2, thres = -1.144 s = 1, alpha = 0.053, E_in(g) = 42.7% , E_in(G) = 5.7%
# iter 343: feat idx = 2, thres = -0.195 s = -1, alpha = 0.059, E_in(g) = 48.6% , E_in(G) = 5.8%
# iter 344: feat idx = 7, thres = 0.241 s = -1, alpha = 0.039, E_in(g) = 46.8% , E_in(G) = 5.7%
# iter 345: feat idx = 7, thres = 0.48 s = 1, alpha = 0.055, E_in(g) = 54.7% , E_in(G) = 5.5%
# iter 346: feat idx = 3, thres = -1.49 s = 1, alpha = 0.047, E_in(g) = 43.7% , E_in(G) = 5.4%
# iter 347: feat idx = 6, thres = 2.259 s = 1, alpha = 0.045, E_in(g) = 50.7% , E_in(G) = 5.5%
# iter 348: feat idx = 7, thres = 1.079 s = -1, alpha = 0.051, E_in(g) = 44.2% , E_in(G) = 5.6%
# iter 349: feat idx = 9, thres = 2.502 s = 1, alpha = 0.046, E_in(g) = 50.0% , E_in(G) = 5.4%
# iter 350: feat idx = 8, thres = 1.623 s = -1, alpha = 0.054, E_in(g) = 45.6% , E_in(G) = 5.6%
# iter 351: feat idx = 5, thres = 2.947 s = 1, alpha = 0.052, E_in(g) = 49.9% , E_in(G) = 5.4%
# iter 352: feat idx = 7, thres = -1.058 s = 1, alpha = 0.054, E_in(g) = 42.4% , E_in(G) = 5.3%
# iter 353: feat idx = 8, thres = 0.39 s = 1, alpha = 0.044, E_in(g) = 53.6% , E_in(G) = 5.2%
# iter 354: feat idx = 8, thres = 0.608 s = -1, alpha = 0.046, E_in(g) = 43.9% , E_in(G) = 5.2%
# iter 355: feat idx = 7, thres = -2.386 s = -1, alpha = 0.049, E_in(g) = 50.4% , E_in(G) = 5.0%
# iter 356: feat idx = 2, thres = -2.073 s = 1, alpha = 0.053, E_in(g) = 44.0% , E_in(G) = 5.2%
# iter 357: feat idx = 8, thres = 3.096 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 5.2%
# iter 358: feat idx = 1, thres = 3.45 s = -1, alpha = 0.053, E_in(g) = 48.0% , E_in(G) = 5.5%
# iter 359: feat idx = 1, thres = 2.3 s = 1, alpha = 0.047, E_in(g) = 50.9% , E_in(G) = 5.2%
# iter 360: feat idx = 1, thres = 0.642 s = -1, alpha = 0.042, E_in(g) = 50.3% , E_in(G) = 5.2%
# iter 361: feat idx = 1, thres = 0.156 s = 1, alpha = 0.051, E_in(g) = 49.2% , E_in(G) = 5.2%
# iter 362: feat idx = 1, thres = -0.05 s = -1, alpha = 0.044, E_in(g) = 49.7% , E_in(G) = 5.2%
# iter 363: feat idx = 1, thres = -1.804 s = 1, alpha = 0.045, E_in(g) = 46.3% , E_in(G) = 5.3%
# iter 364: feat idx = 8, thres = 3.096 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 5.1%
# iter 365: feat idx = 9, thres = 1.425 s = -1, alpha = 0.053, E_in(g) = 44.9% , E_in(G) = 5.3%
# iter 366: feat idx = 5, thres = 3.308 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 5.1%
# iter 367: feat idx = 3, thres = 1.503 s = -1, alpha = 0.054, E_in(g) = 43.3% , E_in(G) = 5.3%
# iter 368: feat idx = 3, thres = 0.174 s = 1, alpha = 0.049, E_in(g) = 48.0% , E_in(G) = 5.4%
# iter 369: feat idx = 3, thres = -0.101 s = -1, alpha = 0.046, E_in(g) = 52.0% , E_in(G) = 5.2%
# iter 370: feat idx = 3, thres = -0.302 s = 1, alpha = 0.048, E_in(g) = 46.6% , E_in(G) = 5.4%
# iter 371: feat idx = 3, thres = -0.155 s = -1, alpha = 0.043, E_in(g) = 52.3% , E_in(G) = 5.2%
# iter 372: feat idx = 9, thres = -0.064 s = -1, alpha = 0.042, E_in(g) = 45.8% , E_in(G) = 5.3%
# iter 373: feat idx = 9, thres = 0.291 s = 1, alpha = 0.043, E_in(g) = 59.1% , E_in(G) = 5.3%
# iter 374: feat idx = 9, thres = 0.2 s = -1, alpha = 0.046, E_in(g) = 41.2% , E_in(G) = 5.3%
# iter 375: feat idx = 9, thres = -0.639 s = 1, alpha = 0.043, E_in(g) = 43.1% , E_in(G) = 5.4%
# iter 376: feat idx = 6, thres = 2.475 s = 1, alpha = 0.05, E_in(g) = 50.5% , E_in(G) = 5.4%
# iter 377: feat idx = 6, thres = 1.086 s = -1, alpha = 0.051, E_in(g) = 44.6% , E_in(G) = 5.3%
# iter 378: feat idx = 0, thres = 3.386 s = 1, alpha = 0.044, E_in(g) = 44.5% , E_in(G) = 5.2%
# iter 379: feat idx = 6, thres = -0.749 s = 1, alpha = 0.051, E_in(g) = 44.6% , E_in(G) = 5.2%
# iter 380: feat idx = 6, thres = -0.964 s = -1, alpha = 0.049, E_in(g) = 54.2% , E_in(G) = 5.1%
# iter 381: feat idx = 5, thres = -0.714 s = 1, alpha = 0.054, E_in(g) = 45.1% , E_in(G) = 5.2%
# iter 382: feat idx = 0, thres = -2.659 s = -1, alpha = 0.052, E_in(g) = 44.9% , E_in(G) = 5.2%
# iter 383: feat idx = 3, thres = -1.68 s = 1, alpha = 0.045, E_in(g) = 44.4% , E_in(G) = 5.1%
# iter 384: feat idx = 7, thres = 2.562 s = 1, alpha = 0.048, E_in(g) = 50.3% , E_in(G) = 5.2%
# iter 385: feat idx = 6, thres = -1.71 s = 1, alpha = 0.052, E_in(g) = 46.5% , E_in(G) = 5.2%
# iter 386: feat idx = 5, thres = 2.947 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 5.2%
# iter 387: feat idx = 2, thres = -2.58 s = 1, alpha = 0.052, E_in(g) = 46.7% , E_in(G) = 5.1%
# iter 388: feat idx = 8, thres = 3.096 s = 1, alpha = 0.05, E_in(g) = 49.9% , E_in(G) = 5.2%
# iter 389: feat idx = 0, thres = -3.943 s = 1, alpha = 0.052, E_in(g) = 48.9% , E_in(G) = 5.2%
# iter 390: feat idx = 5, thres = 3.308 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 5.1%
# iter 391: feat idx = 8, thres = 1.623 s = -1, alpha = 0.051, E_in(g) = 45.6% , E_in(G) = 5.1%
# iter 392: feat idx = 8, thres = 3.096 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 5.1%
# iter 393: feat idx = 4, thres = 1.716 s = -1, alpha = 0.051, E_in(g) = 45.9% , E_in(G) = 5.1%
# iter 394: feat idx = 4, thres = 1.05 s = 1, alpha = 0.048, E_in(g) = 51.7% , E_in(G) = 5.2%
# iter 395: feat idx = 4, thres = 1.289 s = -1, alpha = 0.043, E_in(g) = 46.4% , E_in(G) = 5.0%
# iter 396: feat idx = 9, thres = 2.502 s = 1, alpha = 0.047, E_in(g) = 50.0% , E_in(G) = 5.1%
# iter 397: feat idx = 1, thres = -2.807 s = 1, alpha = 0.052, E_in(g) = 45.2% , E_in(G) = 5.1%
# iter 398: feat idx = 5, thres = 3.308 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 5.0%
# iter 399: feat idx = 8, thres = -1.517 s = 1, alpha = 0.051, E_in(g) = 46.3% , E_in(G) = 5.0%
# iter 400: feat idx = 8, thres = 3.096 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 5.1%
# iter 401: feat idx = 1, thres = 2.707 s = -1, alpha = 0.051, E_in(g) = 47.6% , E_in(G) = 5.0%
# iter 402: feat idx = 1, thres = 2.534 s = 1, alpha = 0.04, E_in(g) = 51.0% , E_in(G) = 5.0%
# iter 403: feat idx = 1, thres = 1.97 s = -1, alpha = 0.041, E_in(g) = 48.6% , E_in(G) = 5.0%
# iter 404: feat idx = 1, thres = 0.95 s = 1, alpha = 0.044, E_in(g) = 48.5% , E_in(G) = 5.0%
# iter 405: feat idx = 1, thres = 0.642 s = -1, alpha = 0.046, E_in(g) = 50.3% , E_in(G) = 4.9%
# iter 406: feat idx = 1, thres = 0.156 s = 1, alpha = 0.047, E_in(g) = 49.2% , E_in(G) = 5.0%
# iter 407: feat idx = 1, thres = -0.936 s = -1, alpha = 0.053, E_in(g) = 49.5% , E_in(G) = 5.3%
# iter 408: feat idx = 1, thres = -1.65 s = 1, alpha = 0.047, E_in(g) = 46.9% , E_in(G) = 5.2%
# iter 409: feat idx = 3, thres = -0.302 s = 1, alpha = 0.038, E_in(g) = 46.6% , E_in(G) = 5.4%
# iter 410: feat idx = 3, thres = -0.69 s = -1, alpha = 0.048, E_in(g) = 53.3% , E_in(G) = 5.0%
# iter 411: feat idx = 0, thres = 0.112 s = 1, alpha = 0.041, E_in(g) = 48.7% , E_in(G) = 5.1%
# iter 412: feat idx = 3, thres = -0.481 s = 1, alpha = 0.046, E_in(g) = 45.8% , E_in(G) = 5.3%
# iter 413: feat idx = 3, thres = -0.572 s = -1, alpha = 0.04, E_in(g) = 53.4% , E_in(G) = 5.1%
# iter 414: feat idx = 0, thres = 0.636 s = -1, alpha = 0.04, E_in(g) = 52.3% , E_in(G) = 5.1%
# iter 415: feat idx = 0, thres = 0.393 s = 1, alpha = 0.04, E_in(g) = 47.6% , E_in(G) = 5.1%
# iter 416: feat idx = 0, thres = -0.056 s = -1, alpha = 0.041, E_in(g) = 50.2% , E_in(G) = 5.1%
# iter 417: feat idx = 0, thres = 0.112 s = 1, alpha = 0.039, E_in(g) = 48.7% , E_in(G) = 5.1%
# iter 418: feat idx = 0, thres = 0.636 s = -1, alpha = 0.039, E_in(g) = 52.3% , E_in(G) = 5.1%
# iter 419: feat idx = 0, thres = 0.393 s = 1, alpha = 0.037, E_in(g) = 47.6% , E_in(G) = 5.1%
# iter 420: feat idx = 3, thres = -0.481 s = 1, alpha = 0.039, E_in(g) = 45.8% , E_in(G) = 5.3%
# iter 421: feat idx = 3, thres = -0.155 s = -1, alpha = 0.037, E_in(g) = 52.3% , E_in(G) = 5.0%
# iter 422: feat idx = 0, thres = -0.056 s = -1, alpha = 0.041, E_in(g) = 50.2% , E_in(G) = 5.3%
# iter 423: feat idx = 9, thres = 0.361 s = -1, alpha = 0.038, E_in(g) = 38.6% , E_in(G) = 5.1%
# iter 424: feat idx = 9, thres = 0.291 s = 1, alpha = 0.043, E_in(g) = 59.1% , E_in(G) = 5.3%
# iter 425: feat idx = 9, thres = 0.2 s = -1, alpha = 0.044, E_in(g) = 41.2% , E_in(G) = 5.0%
# iter 426: feat idx = 9, thres = 0.108 s = 1, alpha = 0.041, E_in(g) = 56.4% , E_in(G) = 5.3%
# iter 427: feat idx = 0, thres = 2.584 s = 1, alpha = 0.039, E_in(g) = 43.1% , E_in(G) = 5.1%
# iter 428: feat idx = 0, thres = 2.979 s = -1, alpha = 0.05, E_in(g) = 54.9% , E_in(G) = 5.1%
# iter 429: feat idx = 0, thres = 2.584 s = 1, alpha = 0.045, E_in(g) = 43.1% , E_in(G) = 5.1%
# iter 430: feat idx = 0, thres = 2.979 s = -1, alpha = 0.041, E_in(g) = 54.9% , E_in(G) = 5.2%
# iter 431: feat idx = 5, thres = 3.308 s = 1, alpha = 0.046, E_in(g) = 49.9% , E_in(G) = 5.0%
# iter 432: feat idx = 2, thres = 2.052 s = -1, alpha = 0.051, E_in(g) = 46.7% , E_in(G) = 5.1%
# iter 433: feat idx = 2, thres = 3.852 s = 1, alpha = 0.047, E_in(g) = 50.2% , E_in(G) = 4.9%
# iter 434: feat idx = 5, thres = -1.308 s = 1, alpha = 0.053, E_in(g) = 40.0% , E_in(G) = 5.0%
# iter 435: feat idx = 8, thres = 3.096 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 4.9%
# iter 436: feat idx = 5, thres = 1.225 s = -1, alpha = 0.05, E_in(g) = 44.4% , E_in(G) = 5.0%
# iter 437: feat idx = 5, thres = 1.019 s = 1, alpha = 0.04, E_in(g) = 55.9% , E_in(G) = 4.9%
# iter 438: feat idx = 2, thres = -1.144 s = 1, alpha = 0.043, E_in(g) = 42.7% , E_in(G) = 5.2%
# iter 439: feat idx = 2, thres = -1.392 s = -1, alpha = 0.044, E_in(g) = 55.7% , E_in(G) = 4.9%
# iter 440: feat idx = 7, thres = -1.058 s = 1, alpha = 0.046, E_in(g) = 42.4% , E_in(G) = 4.9%
# iter 441: feat idx = 0, thres = 3.386 s = 1, alpha = 0.042, E_in(g) = 44.5% , E_in(G) = 4.9%
# iter 442: feat idx = 3, thres = 0.933 s = -1, alpha = 0.043, E_in(g) = 45.0% , E_in(G) = 4.9%
# iter 443: feat idx = 3, thres = -0.223 s = 1, alpha = 0.052, E_in(g) = 46.5% , E_in(G) = 5.1%
# iter 444: feat idx = 7, thres = -0.376 s = -1, alpha = 0.043, E_in(g) = 54.4% , E_in(G) = 4.9%
# iter 445: feat idx = 7, thres = -0.195 s = 1, alpha = 0.052, E_in(g) = 46.2% , E_in(G) = 5.1%
# iter 446: feat idx = 7, thres = 0.259 s = -1, alpha = 0.052, E_in(g) = 46.8% , E_in(G) = 4.8%
# iter 447: feat idx = 4, thres = -1.155 s = -1, alpha = 0.047, E_in(g) = 53.7% , E_in(G) = 5.1%
# iter 448: feat idx = 4, thres = -0.256 s = 1, alpha = 0.044, E_in(g) = 44.5% , E_in(G) = 4.8%
# iter 449: feat idx = 4, thres = -0.416 s = -1, alpha = 0.047, E_in(g) = 54.5% , E_in(G) = 5.1%
# iter 450: feat idx = 4, thres = -0.714 s = 1, alpha = 0.05, E_in(g) = 44.4% , E_in(G) = 4.8%
# iter 451: feat idx = 4, thres = -0.508 s = -1, alpha = 0.042, E_in(g) = 54.4% , E_in(G) = 5.0%
# iter 452: feat idx = 9, thres = 0.361 s = -1, alpha = 0.042, E_in(g) = 38.6% , E_in(G) = 4.8%
# iter 453: feat idx = 9, thres = 0.291 s = 1, alpha = 0.04, E_in(g) = 59.1% , E_in(G) = 5.0%
# iter 454: feat idx = 9, thres = 0.2 s = -1, alpha = 0.041, E_in(g) = 41.2% , E_in(G) = 4.8%
# iter 455: feat idx = 5, thres = 0.745 s = -1, alpha = 0.039, E_in(g) = 42.1% , E_in(G) = 5.1%
# iter 456: feat idx = 5, thres = 0.186 s = 1, alpha = 0.048, E_in(g) = 53.3% , E_in(G) = 4.7%
# iter 457: feat idx = 5, thres = -0.054 s = -1, alpha = 0.044, E_in(g) = 47.0% , E_in(G) = 5.0%
# iter 458: feat idx = 9, thres = 0.291 s = 1, alpha = 0.04, E_in(g) = 59.1% , E_in(G) = 4.9%
# iter 459: feat idx = 4, thres = -0.256 s = 1, alpha = 0.041, E_in(g) = 44.5% , E_in(G) = 4.9%
# iter 460: feat idx = 4, thres = -0.416 s = -1, alpha = 0.039, E_in(g) = 54.5% , E_in(G) = 4.8%
# iter 461: feat idx = 9, thres = 0.361 s = -1, alpha = 0.042, E_in(g) = 38.6% , E_in(G) = 4.9%
# iter 462: feat idx = 5, thres = -0.019 s = 1, alpha = 0.04, E_in(g) = 52.3% , E_in(G) = 4.5%
# iter 463: feat idx = 5, thres = 0.372 s = -1, alpha = 0.041, E_in(g) = 42.6% , E_in(G) = 4.9%
# iter 464: feat idx = 9, thres = 2.502 s = 1, alpha = 0.045, E_in(g) = 50.0% , E_in(G) = 4.6%
# iter 465: feat idx = 4, thres = -1.563 s = 1, alpha = 0.06, E_in(g) = 46.2% , E_in(G) = 4.9%
# iter 466: feat idx = 5, thres = 2.947 s = 1, alpha = 0.051, E_in(g) = 49.9% , E_in(G) = 4.5%
# iter 467: feat idx = 1, thres = -2.59 s = 1, alpha = 0.053, E_in(g) = 44.2% , E_in(G) = 4.8%
# iter 468: feat idx = 7, thres = 2.562 s = 1, alpha = 0.048, E_in(g) = 50.3% , E_in(G) = 4.6%
# iter 469: feat idx = 8, thres = -1.517 s = 1, alpha = 0.05, E_in(g) = 46.3% , E_in(G) = 4.7%
# iter 470: feat idx = 9, thres = 2.502 s = 1, alpha = 0.049, E_in(g) = 50.0% , E_in(G) = 4.6%
# iter 471: feat idx = 9, thres = -1.09 s = 1, alpha = 0.05, E_in(g) = 44.1% , E_in(G) = 4.7%
# iter 472: feat idx = 9, thres = -0.803 s = -1, alpha = 0.047, E_in(g) = 56.3% , E_in(G) = 4.5%
# iter 473: feat idx = 9, thres = -0.771 s = 1, alpha = 0.046, E_in(g) = 43.5% , E_in(G) = 4.7%
# iter 474: feat idx = 9, thres = -0.803 s = -1, alpha = 0.043, E_in(g) = 56.3% , E_in(G) = 4.6%
# iter 475: feat idx = 3, thres = 0.933 s = -1, alpha = 0.046, E_in(g) = 45.0% , E_in(G) = 4.5%
# iter 476: feat idx = 3, thres = 0.575 s = 1, alpha = 0.04, E_in(g) = 50.7% , E_in(G) = 4.5%
# iter 477: feat idx = 2, thres = -1.144 s = 1, alpha = 0.039, E_in(g) = 42.7% , E_in(G) = 4.5%
# iter 478: feat idx = 2, thres = -0.195 s = -1, alpha = 0.047, E_in(g) = 48.6% , E_in(G) = 4.7%
# iter 479: feat idx = 2, thres = 1.014 s = 1, alpha = 0.042, E_in(g) = 55.5% , E_in(G) = 4.5%
# iter 480: feat idx = 2, thres = 1.452 s = -1, alpha = 0.05, E_in(g) = 44.8% , E_in(G) = 4.7%
# iter 481: feat idx = 2, thres = 3.852 s = 1, alpha = 0.049, E_in(g) = 50.2% , E_in(G) = 4.4%
# iter 482: feat idx = 9, thres = 1.275 s = -1, alpha = 0.051, E_in(g) = 42.3% , E_in(G) = 4.7%
# iter 483: feat idx = 9, thres = 2.502 s = 1, alpha = 0.046, E_in(g) = 50.0% , E_in(G) = 4.4%
# iter 484: feat idx = 8, thres = 1.623 s = -1, alpha = 0.052, E_in(g) = 45.6% , E_in(G) = 4.7%
# iter 485: feat idx = 5, thres = 2.947 s = 1, alpha = 0.049, E_in(g) = 49.9% , E_in(G) = 4.5%
# iter 486: feat idx = 5, thres = -1.308 s = 1, alpha = 0.051, E_in(g) = 40.0% , E_in(G) = 4.7%
# iter 487: feat idx = 8, thres = 3.096 s = 1, alpha = 0.048, E_in(g) = 49.9% , E_in(G) = 4.6%
# iter 488: feat idx = 3, thres = 1.503 s = -1, alpha = 0.051, E_in(g) = 43.3% , E_in(G) = 4.8%
# iter 489: feat idx = 0, thres = -2.659 s = -1, alpha = 0.042, E_in(g) = 44.9% , E_in(G) = 4.5%
# iter 490: feat idx = 6, thres = -0.777 s = 1, alpha = 0.042, E_in(g) = 44.5% , E_in(G) = 4.8%
# iter 491: feat idx = 6, thres = -0.964 s = -1, alpha = 0.05, E_in(g) = 54.2% , E_in(G) = 4.5%
# iter 492: feat idx = 9, thres = -1.038 s = 1, alpha = 0.047, E_in(g) = 44.0% , E_in(G) = 4.8%
# iter 493: feat idx = 5, thres = 2.947 s = 1, alpha = 0.045, E_in(g) = 49.9% , E_in(G) = 4.5%
# iter 494: feat idx = 2, thres = -2.58 s = 1, alpha = 0.05, E_in(g) = 46.7% , E_in(G) = 4.8%
# iter 495: feat idx = 8, thres = 3.096 s = 1, alpha = 0.047, E_in(g) = 49.9% , E_in(G) = 4.5%
# iter 496: feat idx = 7, thres = -1.264 s = 1, alpha = 0.049, E_in(g) = 43.5% , E_in(G) = 4.7%
# iter 497: feat idx = 1, thres = -0.936 s = -1, alpha = 0.04, E_in(g) = 49.5% , E_in(G) = 4.6%
# iter 498: feat idx = 1, thres = -1.65 s = 1, alpha = 0.044, E_in(g) = 46.9% , E_in(G) = 4.8%
# iter 499: feat idx = 5, thres = 3.308 s = 1, alpha = 0.05, E_in(g) = 49.9% , E_in(G) = 4.4%
# iter 500: feat idx = 3, thres = -1.344 s = 1, alpha = 0.051, E_in(g) = 44.2% , E_in(G) = 4.9%
# Final error rate: 4.9%

# %%
max_e_in = max(clf_result["g_err_rate"])
print(f"Maximum E_in(g) in 500 iteration is {max_e_in}")
# Out:
# Maximum E_in(g) in 500 iteration is 0.591

# %% [markdown]
# # Problem 13

# %%
iter_list = [60, 160, 260, 360, 460]
for iter_ in iter_list:
    G_in = clf_result["G_err_rate"][:iter_-1]
    print(f"Choice {iter_}: E_in(G) = {round(min(G_in)*100, 4)}%")
# Out:
# Choice 60: E_in(G) = 10.7%
# Choice 160: E_in(G) = 7.0%
# Choice 260: E_in(G) = 5.6%
# Choice 360: E_in(G) = 5.0%
# Choice 460: E_in(G) = 4.7%

# %%
threshold = 0.05
for idx, E_in_G in enumerate(clf_result["G_err_rate"]):
    if E_in_G <= 0.05:
        print(f"The first iteration that E_in(G) <= {threshold} is iteration {idx+1}.")
        break
# Out:
# The first iteration that E_in(G) <= 0.05 is iteration 355.

# %% [markdown]
# # Problem 14

# %%
num_iter = 1
_, _ = adaboost_clf.predict(X_test, y_test, num_iter, isUniform=False, verbose = True)
# Out:
# Iter 0: E_in(g) = 0.455%, E_in(G) = 0.455%

# %% [markdown]
# # Problem 15

# %%
num_iter = 500
_, G_err_test_results = adaboost_clf.predict(X_test, y_test, num_iter, isUniform=True, verbose = False)
print(f"E_out(G_uniform) is {G_err_test_results[-1]}")
# Out:
# E_out(G_uniform) is 0.229

# %% [markdown]
# # Problem 16

# %%
num_iter = 500
_, G_err_test_results = adaboost_clf.predict(X_test, y_test, num_iter, isUniform=False, verbose = False)
print(f"E_out(G_500) is {G_err_test_results[-1]}")
# Out:
# E_out(G_500) is 0.188
